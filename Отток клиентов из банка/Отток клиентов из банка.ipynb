# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Открытие-файла-и-изучение-общей-информации" data-toc-modified-id="Открытие-файла-и-изучение-общей-информации-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Открытие файла и изучение общей информации</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Изучение-признаков" data-toc-modified-id="Изучение-признаков-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Изучение признаков</a></span></li></ul></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование задачи</a></span><ul class="toc-item"><li><span><a href="#Постановка-задачи" data-toc-modified-id="Постановка-задачи-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Постановка задачи</a></span></li><li><span><a href="#Изучение-дисбаланса" data-toc-modified-id="Изучение-дисбаланса-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Изучение дисбаланса</a></span></li><li><span><a href="#Подготовка-признаков" data-toc-modified-id="Подготовка-признаков-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Подготовка признаков</a></span></li></ul></li><li><span><a href="#Построение-моделей-без-учета-дисбаланса" data-toc-modified-id="Построение-моделей-без-учета-дисбаланса-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Построение моделей без учета дисбаланса</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-3.0.2"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.0.3"><span class="toc-item-num">3.0.3&nbsp;&nbsp;</span>Случайный лес</a></span></li></ul></li></ul></li><li><span><a href="#Борьба-с-дисбалансом" data-toc-modified-id="Борьба-с-дисбалансом-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Борьба с дисбалансом</a></span><ul class="toc-item"><li><span><a href="#Balanced-class-weight" data-toc-modified-id="Balanced-class-weight-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Balanced class weight</a></span><ul class="toc-item"><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Случайный лес</a></span></li></ul></li><li><span><a href="#Upsampling" data-toc-modified-id="Upsampling-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Upsampling</a></span><ul class="toc-item"><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Случайный лес</a></span></li></ul></li><li><span><a href="#Сравнение-результатов-и-выбор-итоговой-модели" data-toc-modified-id="Сравнение-результатов-и-выбор-итоговой-модели-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Сравнение результатов и выбор итоговой модели</a></span></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Тестирование модели</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# # Отток клиентов из банка

# %% [markdown]
# Из «Бета-Банка» стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых.
#
# Нужно спрогнозировать, уйдёт клиент из банка в ближайшее время или нет. Нам предоставлены исторические данные о поведении клиентов и расторжении договоров с банком.
#
# Необходимо построить модель с предельно большим значением *F1*-меры. Чтобы сдать проект успешно, нужно довести метрику до 0.59.
#
# Дополнительно необходимо измерять *AUC-ROC*, сравнивая её значение с *F1*-мерой.
#
# Источник данных: [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling)

# %% [markdown]
# **Описание данных**

# %% [markdown]
# Каждая строчка в датасете является информацией о конкретном клиенте банка. В базе данных присутствуют следующие столбцы, которые будут выступать **признаками** в дальнейшем анализе:
#
# `RowNumber` — индекс строки в данных
# `CustomerId` — уникальный идентификатор клиента
# `Surname` — фамилия
# `CreditScore` — кредитный рейтинг
# `Geography` — страна проживания
# `Gender` — пол
# `Age` — возраст
# `Tenure` — сколько лет человек является клиентом банка
# `Balance` — баланс на счёте
# `NumOfProducts` — количество продуктов банка, используемых клиентом
# `HasCrCard` — наличие кредитной карты
# `IsActiveMember` — активность клиента
# `EstimatedSalary` — предполагаемая зарплата
#
# **Целевой признак**:
# `Exited` — факт ухода клиента

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Открытие файла и изучение общей информации

# %%
! pip install scikit-learn==1.1.3

# %%
# Импорт библиотек

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, f1_score, roc_curve, roc_auc_score
from sklearn.utils import shuffle

# %%
# Открытие файла с данными

try:
    data = pd.read_csv('/datasets/Churn.csv')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/Churn.csv')

# %%
# Избавимся от предупреждений

import warnings
warnings.filterwarnings('ignore')

# %%
# Выведем первые 10 строчек, чтобы посмотреть на его структуру

data.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0     2.0       0.00              1          1               1
# ...

# %%
# Выведем общую информацию о датасете

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# Необходимо изменить тип данных в столбце `Tenure`, так как в нем находится количество полных лет, в течение которых человек является клиентом банка. Но сначала необходимо разобраться с пропусками в данном столбце, чтобы избежать ошибок

# %% [markdown]
# Проверим разные способы заполения пропусков в данном столбце, для того чтобы выбрать наиболее оптимальный, то есть тот, который дает минимальное изменение в изначальном распределении данных

# %%
na_percentage = data['Tenure'].isna().sum() / len(data)
print(f'Пропуски в столбце Tenure составляют {(na_percentage):.1%} от всего датасета')
# Out:
# Пропуски в столбце Tenure составляют 9.1% от всего датасета

# %%
# Построим изначальное распределение данных в столбце 'Tenure'

(
    data['Tenure']
    .value_counts().reset_index()
    .sort_values(by='index')
    .plot(kind='bar', y='Tenure', x='index')
)
plt.ylabel('Количество клиентов')
plt.xlabel('Количество лет')
plt.title('Распределение количества лет, в течение которых человек является клиентом банка')
# Out:
# Text(0.5, 1.0, 'Распределение количества лет, в течение которых человек является клиентом банка')

# %% [markdown]
# **Способ 1: заполнение пропусков нулем**

# %%
# Построим распределение по столбцу 'Tenure' с удаленными пропусками

(
    data['Tenure'].fillna(value=0)
    .value_counts().reset_index()
    .sort_values(by='index')
    .plot(kind='bar', y='Tenure', x='index')
)
plt.ylabel('Количество клиентов')
plt.xlabel('Количество лет')
plt.title('Распределение количества лет, в течение которых человек является клиентом банка')
# Out:
# Text(0.5, 1.0, 'Распределение количества лет, в течение которых человек является клиентом банка')

# %% [markdown]
# Заполнение нулем дает сильный выброс на нулевом значении, что сильно отличается от изначального распределения

# %% [markdown]
# **Способ 2: заполнение медианой**

# %%
(
    data['Tenure'].fillna(value=data['Tenure'].median())
    .value_counts().reset_index()
    .sort_values(by='index')
    .plot(kind='bar', y='Tenure', x='index')
)
plt.ylabel('Количество клиентов')
plt.xlabel('Количество лет')
plt.title('Распределение количества лет, в течение которых человек является клиентом банка')
# Out:
# Text(0.5, 1.0, 'Распределение количества лет, в течение которых человек является клиентом банка')

# %% [markdown]
# Заполнение медианой также дает сильный выьрос на значении равном 5, что сильно отличается от изначального распределения

# %% [markdown]
# Так как пропуски составляют меньше 10% от всех данных, мы можем удалить данные строчки для избежания ошибок в дальнейшем анализе. Однако, о наличии пропусков необходимо предупредить разработчиков, ответственных за выгрузку данных, так как могла произойти техническая ошибка

# %%
data = data.dropna(subset=['Tenure']).reset_index(drop=True)
#data.isna().sum()

# %%
# Изменим тип данных в столбце 'Tenure'

data['Tenure'] = data['Tenure'].astype('int64')
#data.dtypes

# %% [markdown]
# ### Изучение признаков

# %%
# Построим гистограммы по численным столбцам

data.drop(['RowNumber', 'CustomerId', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'Exited'], 
          axis=1).hist(figsize=(10, 12), bins=30);

# %% [markdown]
# Распределение в столбце с кредитным рейтингом смещено влево, в отличие от возрастов клиентов со смещенными вправо данными. В выборке преобладают клиенты 35-37 лет с крединтым рейтингом около 650. Данные о балансе распределены примерно нормально, не считая выброса в нуле. В основном, люди являются клиентами банка в течение от года до девяти лет. Предполагаемая зарплата распределна примерно равномерно

# %%
# Построим круговые диаграммы по оставшимся признакам

col_for_pie = ['NumOfProducts', 'HasCrCard', 'IsActiveMember']
names = ['Количество продуктов, используемых клиентом', 'Наличие кредитной карты',
         'Активность клиента']
i = 0

for col in col_for_pie:
    data[col].value_counts().plot(kind='pie', autopct='%1.1f%%')
    plt.ylabel('')
    plt.title(names[i])
    i += 1
    plt.show()

# %% [markdown]
# Большинство клиентов пользуются одним или двумя продуктами компании. Также, у 70.6% клиентов банка есть крединтая карта. Активные и неактивные клиенты распределены примерно равномерно

# %%
# Проверим признаки на наличие корреляции

data.corr()
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004289     0.002330  0.000681 -0.007322
# CustomerId        0.004289    1.000000    -0.001610  0.010379 -0.021418
# CreditScore       0.002330   -0.001610     1.000000 -0.004504 -0.000062
# Age               0.000681    0.010379    -0.004504  1.000000 -0.013134
# Tenure           -0.007322   -0.021418    -0.000062 -0.013134  1.000000
# Balance          -0.005921   -0.007445     0.002804  0.031481 -0.007911
# NumOfProducts     0.009078    0.014604     0.011090 -0.031877  0.011979
# HasCrCard         0.001248   -0.019891    -0.003937 -0.014129  0.027232
# IsActiveMember    0.009536    0.001499     0.030947  0.082269 -0.032178
# EstimatedSalary  -0.004854    0.010029     0.005182 -0.007037  0.010520
# Exited           -0.014562   -0.007040    -0.023950  0.283017 -0.016761
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# Сильной корреляции между признаками не обнаружено

# %% [markdown]
# ## Исследование задачи

# %% [markdown]
# ### Постановка задачи

# %% [markdown]
# Так как нам необходимо предсказать факт ухода клиента (да/нет), перед нами стоит **задача бинарной классификации**
# Для предсказания в данном исследовании будут использоваться следующие модели:
# - Логистическая регрессия
# - Дерево решений
# - Случайный лес

# %% [markdown]
# ### Изучение дисбаланса

# %%
exited_count = pd.DataFrame(data['Exited'].value_counts())
exited_count.columns = ['Количество клиентов']
exited_count['Факт ухода клиента'] = ['нет', 'да']
exited_count = exited_count.set_index('Факт ухода клиента')
display(exited_count)

data['Exited'].value_counts().plot(kind='pie', labels=['нет', 'да'], autopct='%1.1f%%');
plt.ylabel('')
plt.title('Распределение факта ухода клиентов')
plt.show()
# Out:
#                     Количество клиентов
# Факт ухода клиента
# нет                                7237
# да                                 1854

# %% [markdown]
# Присутствует сильный дисбаланс между классами с преобладанием оставшихся клиентов (около 80%)

# %% [markdown]
# ### Подготовка признаков

# %% [markdown]
# Для начала удалим столбцы `RowNumber`, `CustomerId`, `Surname`, так как они скорее всего не пригодятся для построения моделей. Например, врятли от фамилии человека или от его уникального идентификатора может зависеть его доход (даже если это так, врятли это будет применимо к выборке с другими клиентами банка)

# %%
data_adjusted = data.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)

# %% [markdown]
# Разделим данные на тренировочную, валидационную и тестовую выборки

# %%
features = data_adjusted.drop('Exited', axis=1)
target = data_adjusted['Exited']

# Разделим выборку на тренировочную и вылидационную
features_train, features_valid, target_train, target_valid = (
    train_test_split(features, target, test_size=0.4, random_state=12345, stratify=target)
)

# Разделим валидационную выборку на валидационную и тестовую
features_valid, features_test, target_valid, target_test = (
    train_test_split(features_valid, target_valid, test_size=0.5, random_state=12345,
                     stratify=target_valid)
)

#features_train.shape
#features_valid.shape
#features_test.shape
#target_train.shape
#target_valid.shape
#target_test.shape

# %% [markdown]
# Также, для подготовки признаков необходимо провести масштабирование признаков, так как разброс и диапазон данных в столбцах `Balance`, `EstimatedSalary` очень сильно отличаются от остальных данных, например от `Age`. Если не привести данные к одному масштабу, при обучении моделей это может привести к восприятию алгоритмом признака с большим разбросом и диапазоном как наиболее важного, что может привести к переобучению модели

# %%
# Запишем все количественные признаки в список numeric
numeric = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']

# Используем метод StandardScaler
# Он приводит все значения к стандартному нормальному распределению
scaler = StandardScaler()
scaler.fit(features_train[numeric])
features_train[numeric] = scaler.transform(features_train[numeric])
features_valid[numeric] = scaler.transform(features_valid[numeric])
features_test[numeric] = scaler.transform(features_test[numeric])

#features_train.head()
#features_valid.head()
#features_test.head()

# %% [markdown]
# Для подготовки признаков класса object к анализу и построению модели, используем технику OHE. Кодирование признаков необходимо, так как в датасете присутствуют категориальные признаки: `Geography`, `Gender`. Техника порядкового кодирования не подойдет, так как в качестве одна из рассматриваемых моделей - логистическая регрессия, для которой данная техника кодирования не подходит.

# %%
# Сохраним категориальные признаки в список ohe_features
ohe_features = features_train.select_dtypes(include='object').columns.to_list()

# Создадим encoder и обучим его на тренировочных данных
encoder = OneHotEncoder(handle_unknown='ignore', drop='first', sparse=False)
encoder.fit(features_train[ohe_features])

features_train[encoder.get_feature_names_out()] = encoder.transform(features_train[ohe_features])
features_train = features_train.drop(ohe_features, axis=1)
#features_train.head()

features_valid[encoder.get_feature_names_out()] = encoder.transform(features_valid[ohe_features])
features_valid = features_valid.drop(ohe_features, axis=1)
#features_valid.head()

features_test[encoder.get_feature_names_out()] = encoder.transform(features_test[ohe_features])
features_test = features_test.drop(ohe_features, axis=1)
#features_test.head()

# %% [markdown]
# ## Построение моделей без учета дисбаланса

# %% [markdown]
# Для оптимизации кода напишем функции, которые принимают на вход тренировочные и валидационные выборки, и параметр class_weight. Функции будут подбирать оптимальные гипермараметры для моделей, основываясь на показателе f1. Функции будут возвращать оптимальные модели, подобранные гиперпараметры и знечние мерки f1. Также, функции будут выводить полученные параметры, значение f1, матрицу ошибок и график AUC-ROC на экран

# %%
# Функция для регрессии
def regression_builder(features_train, target_train, features_valid, target_valid, class_weight=None):
    model = LogisticRegression(random_state=12345, max_iter=1000, solver='liblinear', 
                               class_weight=class_weight)
    model.fit(features_train, target_train)
    predictions_valid = model.predict(features_valid)
    f1 = f1_score(target_valid, predictions_valid)

    print('Матрица ошибок')
    display(pd.DataFrame(confusion_matrix(target_valid, predictions_valid)))
    
    print(f'Значение f1-score на валидационной выборке: {f1}')

    probabilities_one = model.predict_proba(features_valid)[:, 1]
    auc_score = roc_auc_score(target_valid, probabilities_one)
    print(f'\nЗначение метрики roc-auc score на валидационной выборке: {auc_score}')
    fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one)

    plt.figure()
    plt.plot(fpr, tpr)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.plot([0, 1], [0, 1], linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC-кривая линейной регрессии')
    plt.show() 
    
    return model, f1

# %%
# Функция для дерева решений
def tree_builder(features_train, target_train, features_valid, target_valid, class_weight=None):
    best_model = None
    best_depth = 0
    best_f1 = 0

    for depth in range(1, 11):
    
        model = DecisionTreeClassifier(max_depth=depth, random_state=12345, class_weight=class_weight)
        model.fit(features_train, target_train)
    
        predictions_valid = model.predict(features_valid)
        f1 = f1_score(target_valid, predictions_valid)
    
        if f1 > best_f1:
            best_model = model
            best_depth = depth
            best_f1 = f1
        
    print(f'Лучший результат модели дерева решений:\nГлубина - {best_depth}\n'
          f'F1 - {best_f1}')

    best_predictions_valid = best_model.predict(features_valid)

    print('\nМатрица ошибок')
    display(pd.DataFrame(confusion_matrix(target_valid, best_predictions_valid)))

    probabilities_one = best_model.predict_proba(features_valid)[:, 1]
    auc_score = roc_auc_score(target_valid, probabilities_one)
    print(f'\nЗначение метрики roc-auc score на валидационной выборке: {auc_score}')
    fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one)

    plt.figure()
    plt.plot(fpr, tpr)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.plot([0, 1], [0, 1], linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC-кривая дерева решений')
    plt.show()
    
    return best_model, best_depth, best_f1

# %%
# Функция для случайного леса
def forest_builder(features_train, target_train, features_valid, target_valid, class_weight=None):
    best_model = None
    best_f1 = 0
    best_depth = 0
    best_est = 0

    for est in range(10, 51, 10):
        for depth in range(1, 20):
            model = RandomForestClassifier(n_estimators=est, max_depth=depth, random_state=12345, 
                                          class_weight=class_weight)
            model.fit(features_train, target_train)
        
            predictions_valid = model.predict(features_valid)
            f1 = f1_score(target_valid, predictions_valid)
        
            if f1 > best_f1:
                best_model = model
                best_depth = depth
                best_est = est
                best_f1 = f1
            
    print(f'Лучший результат модели случайного леса:\nГлубина - {best_depth}\n'
      f'Число деревьев в случайном лесу - {best_est}\nF1 - {best_f1}')

    best_predictions_valid = best_model.predict(features_valid)

    print('\nМатрица ошибок')
    display(pd.DataFrame(confusion_matrix(target_valid, best_predictions_valid)))

    probabilities_one = best_model.predict_proba(features_valid)[:, 1]
    auc_score = roc_auc_score(target_valid, probabilities_one)
    print(f'\nЗначение метрики roc-auc score на валидационной выборке: {auc_score}')
    fpr, tpr, thresholds = roc_curve(target_valid, probabilities_one)

    plt.figure()
    plt.plot(fpr, tpr)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.plot([0, 1], [0, 1], linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC-кривая случайного леса')
    plt.show() 
    
    return best_model, best_depth, best_est, best_f1

# %% [markdown]
# #### Логистическая регрессия

# %%
model_regression, f1_regression = (
    regression_builder(features_train, target_train, features_valid, target_valid)
)
# Out:
# Матрица ошибок
#       0   1
# 0  1399  48
# 1   288  83
# Значение f1-score на валидационной выборке: 0.3306772908366534
#
# Значение метрики roc-auc score на валидационной выборке: 0.7893010355098474

# %% [markdown]
# #### Дерево решений

# %%
model_tree, best_depth_tree, f1_tree = (
    tree_builder(features_train, target_train, features_valid, target_valid)
)
# Out:
# Лучший результат модели дерева решений:
# Глубина - 7
# F1 - 0.5815126050420169
#
# Матрица ошибок
#       0    1
# 0  1396   51
# 1   198  173
# Значение метрики roc-auc score на валидационной выборке: 0.8245379882534177

# %% [markdown]
# #### Случайный лес

# %%
model_forest, best_depth_forest, best_est, f1_forest = (
    forest_builder(features_train, target_train, features_valid, target_valid)
)
# Out:
# Лучший результат модели случайного леса:
# Глубина - 19
# Число деревьев в случайном лесу - 50
# F1 - 0.6121112929623569
#
# Матрица ошибок
#       0    1
# 0  1394   53
# 1   184  187
# Значение метрики roc-auc score на валидационной выборке: 0.8656007316932328

# %% [markdown]
# Таким образом, без борьбы с дисбалансом **случайный лес** дал наилучший результат показателя f1 на валидационной выборке - примерно 0.61.
# Подобранные гиперпараментры:
# - Глубина - 19
# - Число деревьев - 50

# %% [markdown]
# ## Борьба с дисбалансом

# %% [markdown]
# Улучшим качество модели, учитывая борьбу с дисбалансом. Рассмотрим два способа и выберем лучший по результату f1 на валидационной выборке:
# - Балансирование классов
# - Upsampling
#
# Downsampling не будем рассматривать в данном проекте, так как удалять около 60% данных нецелесообразно при небольшом изначальном размере датасета

# %% [markdown]
# ### Balanced class weight

# %% [markdown]
# #### Логистическая регрессия

# %%
model_regression_balanced, f1_regression_balanced = (
    regression_builder(features_train, target_train, features_valid, target_valid, 
                       class_weight='balanced')
)
# Out:
# Матрица ошибок
#       0    1
# 0  1019  428
# 1   100  271
# Значение f1-score на валидационной выборке: 0.5065420560747663
#
# Значение метрики roc-auc score на валидационной выборке: 0.790763304317698

# %% [markdown]
# #### Дерево решений

# %%
model_tree_balanced, best_depth_tree_balanced, f1_tree_balanced = (
    tree_builder(features_train, target_train, features_valid, target_valid, class_weight='balanced')
)
# Out:
# Лучший результат модели дерева решений:
# Глубина - 6
# F1 - 0.583084577114428
#
# Матрица ошибок
#       0    1
# 0  1106  341
# 1    78  293
# Значение метрики roc-auc score на валидационной выборке: 0.8353643657199484

# %% [markdown]
# #### Случайный лес

# %%
model_forest_balanced, best_depth_forest_balanced, best_est_balanced, f1_forest_balanced = (
    forest_builder(features_train, target_train, features_valid, target_valid, class_weight='balanced')
)
# Out:
# Лучший результат модели случайного леса:
# Глубина - 9
# Число деревьев в случайном лесу - 40
# F1 - 0.6428571428571429
#
# Матрица ошибок
#       0    1
# 0  1286  161
# 1   119  252
# Значение метрики roc-auc score на валидационной выборке: 0.872344864456064

# %% [markdown]
# ### Upsampling

# %%
# Напишем функцию upsample:
# Ее аргументами являются признаки, целевой признак и на сколько необходимо увеличить выборку
# Функция возращает увеличенную в размере выборку

def upsample(features, target, repeat):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    
    features_upsampled, target_upsampled = shuffle(
        features_upsampled, target_upsampled, random_state=12345)
    
    return features_upsampled, target_upsampled

# %%
# Посчитаем параметр round как отношение размера большего класса выборки к меньшему

repeat = round(len(data[data['Exited'] == 0]) / len(data[data['Exited'] == 1]))
# repeat

# %%
# Сохраним выборки после использования функции unsample()

features_upsampled, target_upsampled = upsample(features_train, target_train, repeat)
#len(features_upsampled) / len(target_upsampled)

# %% [markdown]
# #### Логистическая регрессия

# %%
model_regression_upsampled, f1_regression_upsampled = (
    regression_builder(features_upsampled, target_upsampled, features_valid, target_valid)
)
# Out:
# Матрица ошибок
#       0    1
# 0  1010  437
# 1    98  273
# Значение f1-score на валидационной выборке: 0.5050878815911193
#
# Значение метрики roc-auc score на валидационной выборке: 0.790767029843323

# %% [markdown]
# #### Дерево решений

# %%
model_tree_upsampled, best_depth_tree_upsampled, f1_tree_upsampled = (
    tree_builder(features_upsampled, target_upsampled, features_valid, target_valid)
)
# Out:
# Лучший результат модели дерева решений:
# Глубина - 6
# F1 - 0.5825049701789264
#
# Матрица ошибок
#       0    1
# 0  1105  342
# 1    78  293
# Значение метрики roc-auc score на валидационной выборке: 0.8347040163029001

# %% [markdown]
# #### Случайный лес

# %%
model_forest_upsampled, best_depth_forest_upsampled, best_est_upsampled, f1_forest_upsampled = (
    forest_builder(features_upsampled, target_upsampled, features_valid, target_valid)
)
# Out:
# Лучший результат модели случайного леса:
# Глубина - 12
# Число деревьев в случайном лесу - 20
# F1 - 0.646074646074646
#
# Матрица ошибок
#       0    1
# 0  1292  155
# 1   120  251
# Значение метрики roc-auc score на валидационной выборке: 0.8668152530470143

# %% [markdown]
# ### Сравнение результатов и выбор итоговой модели

# %% [markdown]
# Выведем таблицу со значениями f1 на валидационных выборках для всех рассматриваемых моделей и способов учета дисбаланса

# %%
f1_table = pd.DataFrame(
    {
        'Модель': ['Логистическая регрессия', 'Дерево решений', 'Случайный лес'],
        'Без учета дисбаланса': [f1_regression, f1_tree, f1_forest],
        'Balanced class weight': [f1_regression_balanced, f1_tree_balanced, f1_forest_balanced],
         'Upsampling': [f1_regression_upsampled, f1_tree_upsampled, f1_forest_upsampled]
    }
)
f1_table = f1_table.set_index('Модель')
f1_table
# Out:
#                          Без учета дисбаланса  Balanced class weight  \
# Модель
# Логистическая регрессия              0.330677               0.506542
# Дерево решений                       0.581513               0.583085
# Случайный лес                        0.612111               0.642857
#
#                          Upsampling
# Модель
# Логистическая регрессия    0.505088
# Дерево решений             0.582505
# Случайный лес              0.646075

# %% [markdown]
# Таким образом, **случайный лес с использованием метода upsampling** дал наилучший результат f1 на валидационной выборке. Подобранные гиперпараметры:
# - Глубина леса - 12
# - Число деревьев в случайном лесу - 20

# %% [markdown]
# ## Тестирование модели

# %%
predictions_test = model_forest_upsampled.predict(features_test)
f1_test = f1_score(target_test, predictions_test)
print(f'Значение f1 на тестовой выборке: {f1_test}')

print('\nМатрица ошибок')
display(pd.DataFrame(confusion_matrix(target_test, predictions_test)))

probabilities_one_test = model_forest_upsampled.predict_proba(features_test)[:, 1]
auc_score_test = roc_auc_score(target_test, probabilities_one_test)
print(f'\nЗначение метрики roc-auc score на тестовой выборке: {auc_score_test}')
fpr_test, tpr_test, thresholds_test = roc_curve(target_test, probabilities_one_test)

plt.figure()
plt.plot(fpr_test, tpr_test)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая случайного леса')
plt.show()
# Out:
# Значение f1 на тестовой выборке: 0.5923984272608126
#
# Матрица ошибок
#       0    1
# 0  1282  166
# 1   145  226
# Значение метрики roc-auc score на тестовой выборке: 0.8417828848416256

# %% [markdown]
# Значение f1 получилось ниже, чем на валидационной. Тем не менее, подобранная модель прошла тестирование: значение f1 получилось примерно 0.59, что соответствует цели проекта

# %% [markdown]
# ## Вывод

# %% [markdown]
# Таким образом, целью данного проекта было подобрать модель, которая прогнозирует расторжение клиентом договора с банком и его уход. Была поставлена задача бинарной классификации с желаемым результатом показателя f1 не менее 0.59. В проекте были использованы следующие модели для ее реализации:
# - Логистическая регрессия
# - Дерево решений
# - Случайный лес
#
# Сначала мы изучили данные,разбили данные на тренировочную, валидационную и тестовую выборки и подготовили признаки к анализу, а именно: провели масштабирование и подготовили качественные признаки к анализу с помощью метода OHE.
#
# Далее, мы изучили дисбаланс данных: в датасете присутствует 20% клиентов, покинувших банк, и 80% оставшихся. При построении моделей без учета дисбаланса лучший результат показала модель случайного леса с f1 = 0.61.
#
# Потом мы построили модели с учетом дисбаланса с помощью двух методов: балансирование классов с помощью параметра class_weight и с помощью увеличения выборки. В обоих методах лучший результат на валидационной выборке также дала модель случайного леса с f1 примерно равном 0.64, однако при использовании метода upsampling результат f1 был немного выше, поэтому данная модель была выбрана для тестирования.
#
# При проверке выбранной модели случайного леса с 20 деревьями с максимальной глубиной 12 на тестовой выборке был достигнут результат f1 = 0.59. Результат ниже, чем на валидационной выборке, но желаемое значение мерки f1 на тестовой выборке было достигнуто. Следовательно, модель может быть представлена заказчику.
